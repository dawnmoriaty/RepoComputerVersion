# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17274, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 17274 (delta 1), reused 0 (delta 0), pack-reused 17270 (from 3)
# Receiving objects: 100% (17274/17274), 16.12 MiB | 14.59 MiB/s, done.
# Resolving deltas: 100% (11856/11856), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 70.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.7 MB/s eta 0:00:00
# ...

# %%
# !nvidia-smi
# Out:
# Fri Mar 21 07:48:45 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !apt-get install unrar
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.

# %%
# !unrar x /content/selected_data.rar
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
hyp_content = """# Hyperparameters for general training
lr0: 0.001  # Đặt learning rate ban đầu thành 0.001
lrf: 0.2   # Final learning rate (lr0 * lrf)
momentum: 0.937
weight_decay: 0.0005
warmup_epochs: 3.0
warmup_momentum: 0.8
warmup_bias_lr: 0.1
box: 0.05
cls: 0.5
cls_pw: 1.0
obj: 1.0
obj_pw: 1.0
iou_t: 0.20
anchor_t: 4.0
fl_gamma: 1.5  # Bật focal loss để cải thiện precision
hsv_h: 0.015
hsv_s: 0.7
hsv_v: 0.4
degrees: 10.0  # Tăng xoay ảnh
translate: 0.2  # Tăng dịch ảnh
scale: 0.9     # Tăng phóng to/thu nhỏ
shear: 0.1     # Tăng cắt ảnh
perspective: 0.0
flipud: 0.0
fliplr: 0.5
mosaic: 1.0
mixup: 0.0
copy_paste: 0.0
"""

with open("/content/yolov5/data/hyp.scratch.yaml", "w") as file:
    file.write(hyp_content)

print("File hyp.scratch.yaml đã được cập nhật với lr0 = 0.001!")
# Out:
# File hyp.scratch.yaml đã được cập nhật với lr0 = 0.001!

# %%
yaml_content = """path: /content/yolov5/dataset
train: images/train
val: images/val

names:
  0: "la_khoai_mi"
"""

with open("/content/yolov5/data/cassava.yaml", "w") as file:
    file.write(yaml_content)

print("File cassava.yaml đã được cập nhật!")
# Out:
# File cassava.yaml đã được cập nhật!

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data /content/yolov5/data/cassava.yaml --weights yolov5m.pt --hyp /content/yolov5/data/hyp.scratch.yaml --patience 10
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#       53/99      7.83G    0.03429    0.00527          0         76        640:  92% 173/188 [02:18<00:14,  1.03it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       53/99      7.83G    0.03429   0.005272          0        102        640:  93% 174/188 [02:18<00:11,  1.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       53/99      7.83G    0.03429   0.005278          0        108        640:  93% 175/188 [02:19<00:10,  1.30it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
# !zip -r /content/yolov5_train_results_exp.zip /content/yolov5/runs/train/exp
from google.colab import files
files.download('/content/yolov5_train_results_exp.zip')
# Out:
#   adding: content/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/val_batch2_pred.jpg (deflated 3%)
#   adding: content/yolov5/runs/train/exp/train_batch0.jpg (deflated 3%)
#   adding: content/yolov5/runs/train/exp/val_batch1_labels.jpg (deflated 4%)
#   adding: content/yolov5/runs/train/exp/P_curve.png (deflated 16%)
#   adding: content/yolov5/runs/train/exp/val_batch1_pred.jpg (deflated 3%)
#   adding: content/yolov5/runs/train/exp/val_batch0_labels.jpg (deflated 7%)
#   adding: content/yolov5/runs/train/exp/F1_curve.png (deflated 17%)
#   adding: content/yolov5/runs/train/exp/confusion_matrix.png (deflated 38%)
#   adding: content/yolov5/runs/train/exp/labels_correlogram.jpg (deflated 37%)
#   adding: content/yolov5/runs/train/exp/R_curve.png (deflated 17%)
#   adding: content/yolov5/runs/train/exp/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/weights/last.pt (deflated 8%)
# ...
